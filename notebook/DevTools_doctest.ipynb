# %% [markdown]
# #  Testing through documentation
#
# 26.3 doctest — Test interactive Python examples
# https://docs.python.org/3/library/doctest.html
#
#
# <b>doctest</b> lets you <b>test</b> your code by running <b>examples embedded in the documentation</b> and verifying that they produce the expected results.
#
# It works by parsing the help text to find examples, running them, then comparing the output text against the expected value.
#
# Many developers find doctest <b>easier</b> than unittest because in its simplest form, there is no API to learn before using it.
#
# However, as the examples become more complex <b>the lack of fixture management</b> can make writing doctest tests more <b>cumbersome</b> than using unittest.

# %% [markdown]
# ## 1 Getting Started
#
# <b>doctest</b> looks for lines
#
# * <b>beginning</b> with ：
#
#    * **>>>** the interpreter prompt to find the beginning of a test case.
#
# * <b>ended</b> with
#
#     * a blank line</b>,
#
#     * the next interpreter prompt.
#
# Here, <b>fun_multiply()</b> has two examples given in the module: ```doctest_simple.py```

# %%
# %%file ./code/doctest/doctest_simple.py

def fun_multiply(a, b):
    """
    >>> fun_multiply(2, 3)
    6
    >>> fun_multiply('a', 3)
    'aaa'
    """
    return a * b
# Out:
# Overwriting ./code/doctest/doctest_simple.py

# %% [markdown]
# To run the tests, use
#
# <b>doctest as the main program</b> via the <b>-m</b> option to the interpreter:
#
# * python **-m doctest** *.py

# %%
# !python -m doctest ./code/doctest/doctest_simple.py

# %% [markdown]
# Usually **no output** is produced .It means **all the examples worked**
#
# Pass ** -v ** to the script, and **doctest** prints a detailed log of what it’s trying, and prints a summary at the end:

# %%
# !python -m doctest -v ./code/doctest/doctest_simple.py
# Out:
# Trying:
#     fun_multiply(2, 3)
# Expecting:
#     6
# ok
# Trying:
#     fun_multiply('a', 3)
# Expecting:
#     'aaa'
# ok
# 1 items had no tests:
#     doctest_simple
# 1 items passed all tests:
#    2 tests in doctest_simple.fun_multiply
# 2 tests in 2 items.
# 2 passed and 0 failed.
# Test passed.

# %% [markdown]
# **Examples** cannot usually stand on their own as explanations of a function,
#
# **doctest** also lets you keep the **surrounding text** you would normally include in the documentation.
#
# **Intervening text** is **ignored**, and can have any format as long as it does not look like a test case.

# %%
# %%file ./code/doctest/doctest_simple_with_docs.py

def fun_multiply(a, b):
    """Returns a * b.

    Works with numbers:
    
    >>> fun_multiply(2, 3)
    6

    and strings:
    
    >>> fun_multiply('a', 3)
    'aaa'
    """
    return a * b

def fun_add(a, b):
    """Returns a + b.

    Works with numbers:
    
    >>> fun_add(2, 3)
    5
    
    and strings:
    
    >>> fun_add('1', '3')
    '13'
    """
    return a + b
# Out:
# Overwriting ./code/doctest/doctest_simple_with_docs.py

# %% [markdown]
# The surrounding text in the updated docstring
#
# * <b>useful to a human reader</b>,
#
# * <b>ignored by doctest</b>,
#
# the results are the same.

# %%
# !python -m doctest -v ./code/doctest/doctest_simple_with_docs.py
# Out:
# Trying:
#     fun_add(2, 3)
# Expecting:
#     5
# ok
# Trying:
#     fun_add('1', '3')
# Expecting:
#     '13'
# ok
# Trying:
#     fun_multiply(2, 3)
# Expecting:
#     6
# ok
# Trying:
#     fun_multiply('a', 3)
# Expecting:
#     'aaa'
# ok
# 1 items had no tests:
#     doctest_simple_with_docs
# 2 items passed all tests:
#    2 tests in doctest_simple_with_docs.fun_add
#    2 tests in doctest_simple_with_docs.fun_multiply
# 4 tests in 3 items.
# 4 passed and 0 failed.
# Test passed.

# %% [markdown]
# # run doctest directly
#
# The simplest way to start using doctest  is to
#
# * **end** each module M with:
#
# ```python
# if __name__ == "__main__":
#    import doctest
#    doctest.testmod()
# ```
#
# **doctest** then examines docstrings in module M.

# %%
# %%file  ./code/doctest/doctest_with_testmod.py

def fun_multiply(a, b):
    """Returns a * b.

    Works with numbers:
    
    >>> fun_multiply(2, 3)
    6

    and strings:
    
    >>> fun_multiply('a', 3)
    'aaa'
    """
    return a * b

def fun_add(a, b):
    """Returns a + b.

    Works with numbers:
    
    >>> fun_add(2, 3)
    5
    
    and strings:
    
    >>> fun_add('1', '3')
    '13'
    """
    return a + b

if __name__ == "__main__":
    import doctest
    doctest.testmod()
# Out:
# Overwriting ./code/doctest/doctest_with_testmod.py

# %%
# !python ./code/doctest/doctest_with_testmod.py

# %%
# !python ./code/doctest/doctest_with_testmod.py -v
# Out:
# Trying:
#     fun_add(2, 3)
# Expecting:
#     5
# ok
# Trying:
#     fun_add('1', '3')
# Expecting:
#     '13'
# ok
# Trying:
#     fun_multiply(2, 3)
# Expecting:
#     6
# ok
# Trying:
#     fun_multiply('a', 3)
# Expecting:
#     'aaa'
# ok
# 1 items had no tests:
#     __main__
# 2 items passed all tests:
#    2 tests in __main__.fun_add
#    2 tests in __main__.fun_multiply
# 4 tests in 3 items.
# 4 passed and 0 failed.
# Test passed.

# %% [markdown]
# ## DocTest of iapws.iapws97
#
# https://github.com/jjgomera/iapws

# %%
# !pip install iapws

# %% [markdown]
# In debian you can find in **official repositories** in jessie.
#
# In ubuntu it's in official repositories from ubuntu saucy (13.10)

# %%
# !sudo apt install iapws

# %%
# %%file ./code/doctest/doctest_iapws97.py

from iapws import iapws97

if __name__ == "__main__":
    import doctest
    doctest.testmod(iapws97)
# Out:
# Overwriting ./code/doctest/doctest_iapws97.py

# %%
# !python ./code/doctest/doctest_iapws97.py -v
# Out:
# Trying:
#     water=IAPWS97(T=170+273.15,x=0.5)
# Expecting nothing
# ok
# Trying:
#     water.Liquid.cp, water.Vapor.cp, water.Liquid.w, water.Vapor.w
# Expecting:
#     4.3695 2.5985 1418.3 498.78
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 4285, in iapws.iapws97.IAPWS97
# Failed example:
#     water.Liquid.cp, water.Vapor.cp, water.Liquid.w, water.Vapor.w
# Expected:
#     4.3695 2.5985 1418.3 498.78
# Got:
#     (4.369498593233083, 2.5985140134188485, 1418.2631646730363, 498.7751280146938)
# Trying:
#     water=IAPWS97(T=325+273.15,x=0.5)
# Expecting nothing
# ok
# Trying:
#     water.P, water.Liquid.v, water.Vapor.v, water.Liquid.h, water.Vapor.h
# Expecting:
#     12.0505 0.00152830 0.0141887 1493.37 2684.48
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 4288, in iapws.iapws97.IAPWS97
# Failed example:
#     water.P, water.Liquid.v, water.Vapor.v, water.Liquid.h, water.Vapor.h
# Expected:
#     12.0505 0.00152830 0.0141887 1493.37 2684.48
# Got:
#     (12.050521561788548, 0.0015282963642239107, 0.01418871890465692, 1493.3719388844431, 2684.4830448129105)
# Trying:
#     water=IAPWS97(T=50+273.15,P=0.0006112127)
# Expecting nothing
# ok
# Trying:
#     water.cp0, water.cv0, water.h0, water.s0, water.w0
# Expecting:
#     1.8714 1.4098 2594.66 9.471 444.93
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 4291, in iapws.iapws97.IAPWS97
# Failed example:
#     water.cp0, water.cv0, water.h0, water.s0, water.w0
# Expected:
#     1.8714 1.4098 2594.66 9.471 444.93
# Got:
#     (1.871360747319765, 1.409834747319765, 2594.6567932077483, 9.470869208571813, 444.93320591346475)
# Trying:
#     _Backward1_P_hs(0.001,0)
# Expecting:
#     0.0009800980612
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 907, in iapws.iapws97._Backward1_P_hs
# Failed example:
#     _Backward1_P_hs(0.001,0)
# Expected:
#     0.0009800980612
# Got:
#     0.0009800980612120335
# Trying:
#     _Backward1_P_hs(90,0)
# Expecting:
#     91.92954727
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 909, in iapws.iapws97._Backward1_P_hs
# Failed example:
#     _Backward1_P_hs(90,0)
# Expected:
#     91.92954727
# Got:
#     91.92954726666242
# Trying:
#     _Backward1_P_hs(1500,3.4)
# Expecting:
#     58.68294423
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 911, in iapws.iapws97._Backward1_P_hs
# Failed example:
#     _Backward1_P_hs(1500,3.4)
# Expected:
#     58.68294423
# Got:
#     58.68294422962954
# Trying:
#     _Backward1_T_Ph(3,500)
# Expecting:
#     391.798509
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 814, in iapws.iapws97._Backward1_T_Ph
# Failed example:
#     _Backward1_T_Ph(3,500)
# Expected:
#     391.798509
# Got:
#     391.7985087624256
# Trying:
#     _Backward1_T_Ph(80,1500)
# Expecting:
#     611.041229
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 816, in iapws.iapws97._Backward1_T_Ph
# Failed example:
#     _Backward1_T_Ph(80,1500)
# Expected:
#     611.041229
# Got:
#     611.0412294026648
# Trying:
#     _Backward1_T_Ps(3,0.5)
# Expecting:
#     307.842258
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 860, in iapws.iapws97._Backward1_T_Ps
# Failed example:
#     _Backward1_T_Ps(3,0.5)
# Expected:
#     307.842258
# Got:
#     307.84225764107606
# Trying:
#     _Backward1_T_Ps(80,3)
# Expecting:
#     565.899909
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 862, in iapws.iapws97._Backward1_T_Ps
# Failed example:
#     _Backward1_T_Ps(80,3)
# Expected:
#     565.899909
# Got:
#     565.8999087585007
# Trying:
#     _Backward2a_P_hs(2800,6.5)
# Expecting:
#     1.371012767
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1583, in iapws.iapws97._Backward2a_P_hs
# Failed example:
#     _Backward2a_P_hs(2800,6.5)
# Expected:
#     1.371012767
# Got:
#     1.3710127667987446
# Trying:
#     _Backward2a_P_hs(2800,9.5)
# Expecting:
#     0.001879743844
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1585, in iapws.iapws97._Backward2a_P_hs
# Failed example:
#     _Backward2a_P_hs(2800,9.5)
# Expected:
#     0.001879743844
# Got:
#     0.0018797438437697551
# Trying:
#     _Backward2a_P_hs(4100,9.5)
# Expecting:
#     0.1024788997
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1587, in iapws.iapws97._Backward2a_P_hs
# Failed example:
#     _Backward2a_P_hs(4100,9.5)
# Expected:
#     0.1024788997
# Got:
#     0.10247889965432319
# Trying:
#     _Backward2a_T_Ph(0.001,3000)
# Expecting:
#     534.433241
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1198, in iapws.iapws97._Backward2a_T_Ph
# Failed example:
#     _Backward2a_T_Ph(0.001,3000)
# Expected:
#     534.433241
# Got:
#     534.4332413817319
# Trying:
#     _Backward2a_T_Ph(3,4000)
# Expecting:
#     1010.77577
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1200, in iapws.iapws97._Backward2a_T_Ph
# Failed example:
#     _Backward2a_T_Ph(3,4000)
# Expected:
#     1010.77577
# Got:
#     1010.7757656610391
# Trying:
#     _Backward2a_T_Ps(0.1,7.5)
# Expecting:
#     399.517097
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1386, in iapws.iapws97._Backward2a_T_Ps
# Failed example:
#     _Backward2a_T_Ps(0.1,7.5)
# Expected:
#     399.517097
# Got:
#     399.5170966554111
# Trying:
#     _Backward2a_T_Ps(2.5,8)
# Expecting:
#     1039.84917
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1388, in iapws.iapws97._Backward2a_T_Ps
# Failed example:
#     _Backward2a_T_Ps(2.5,8)
# Expected:
#     1039.84917
# Got:
#     1039.8491732352315
# Trying:
#     _Backward2b_P_hs(2800,6)
# Expecting:
#     4.793911442
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1637, in iapws.iapws97._Backward2b_P_hs
# Failed example:
#     _Backward2b_P_hs(2800,6)
# Expected:
#     4.793911442
# Got:
#     4.793911442032859
# Trying:
#     _Backward2b_P_hs(3600,6)
# Expecting:
#     83.95519209
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1639, in iapws.iapws97._Backward2b_P_hs
# Failed example:
#     _Backward2b_P_hs(3600,6)
# Expected:
#     83.95519209
# Got:
#     83.95519209481726
# Trying:
#     _Backward2b_P_hs(3600,7)
# Expecting:
#     7.527161441
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1641, in iapws.iapws97._Backward2b_P_hs
# Failed example:
#     _Backward2b_P_hs(3600,7)
# Expected:
#     7.527161441
# Got:
#     7.527161440645893
# Trying:
#     _Backward2b_T_Ph(5,4000)
# Expecting:
#     1015.31583
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1251, in iapws.iapws97._Backward2b_T_Ph
# Failed example:
#     _Backward2b_T_Ph(5,4000)
# Expected:
#     1015.31583
# Got:
#     1015.3158253261162
# Trying:
#     _Backward2b_T_Ph(25,3500)
# Expecting:
#     875.279054
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1253, in iapws.iapws97._Backward2b_T_Ph
# Failed example:
#     _Backward2b_T_Ph(25,3500)
# Expected:
#     875.279054
# Got:
#     875.2790537215022
# Trying:
#     _Backward2b_T_Ps(8,6)
# Expecting:
#     600.484040
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1446, in iapws.iapws97._Backward2b_T_Ps
# Failed example:
#     _Backward2b_T_Ps(8,6)
# Expected:
#     600.484040
# Got:
#     600.4840398130762
# Trying:
#     _Backward2b_T_Ps(90,6)
# Expecting:
#     1038.01126
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1448, in iapws.iapws97._Backward2b_T_Ps
# Failed example:
#     _Backward2b_T_Ps(90,6)
# Expected:
#     1038.01126
# Got:
#     1038.0112591933694
# Trying:
#     _Backward2c_P_hs(2800,5.1)
# Expecting:
#     94.39202060
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1692, in iapws.iapws97._Backward2c_P_hs
# Failed example:
#     _Backward2c_P_hs(2800,5.1)
# Expected:
#     94.39202060
# Got:
#     94.3920205997893
# Trying:
#     _Backward2c_P_hs(2800,5.8)
# Expecting:
#     8.414574124
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1694, in iapws.iapws97._Backward2c_P_hs
# Failed example:
#     _Backward2c_P_hs(2800,5.8)
# Expected:
#     8.414574124
# Got:
#     8.414574123957314
# Trying:
#     _Backward2c_P_hs(3400,5.8)
# Expecting:
#     83.76903879
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1696, in iapws.iapws97._Backward2c_P_hs
# Failed example:
#     _Backward2c_P_hs(3400,5.8)
# Expected:
#     83.76903879
# Got:
#     83.76903879069711
# Trying:
#     _Backward2c_T_Ph(40,2700)
# Expecting:
#     743.056411
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1305, in iapws.iapws97._Backward2c_T_Ph
# Failed example:
#     _Backward2c_T_Ph(40,2700)
# Expected:
#     743.056411
# Got:
#     743.0564109621092
# Trying:
#     _Backward2c_T_Ph(60,3200)
# Expecting:
#     882.756860
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1307, in iapws.iapws97._Backward2c_T_Ph
# Failed example:
#     _Backward2c_T_Ph(60,3200)
# Expected:
#     882.756860
# Got:
#     882.756859649251
# Trying:
#     _Backward2c_T_Ps(20,5.75)
# Expecting:
#     697.992849
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1503, in iapws.iapws97._Backward2c_T_Ps
# Failed example:
#     _Backward2c_T_Ps(20,5.75)
# Expected:
#     697.992849
# Got:
#     697.9928494638522
# Trying:
#     _Backward2c_T_Ps(80,5.75)
# Expecting:
#     949.017998
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1505, in iapws.iapws97._Backward2c_T_Ps
# Failed example:
#     _Backward2c_T_Ps(80,5.75)
# Expected:
#     949.017998
# Got:
#     949.0179975704459
# Trying:
#     _Backward3a_P_hs(1700,3.8)
# Expecting:
#     25.55703246
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2612, in iapws.iapws97._Backward3a_P_hs
# Failed example:
#     _Backward3a_P_hs(1700,3.8)
# Expected:
#     25.55703246
# Got:
#     25.557032462895986
# Trying:
#     _Backward3a_P_hs(2000,4.2)
# Expecting:
#     45.40873468
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2614, in iapws.iapws97._Backward3a_P_hs
# Failed example:
#     _Backward3a_P_hs(2000,4.2)
# Expected:
#     45.40873468
# Got:
#     45.40873467774791
# Trying:
#     _Backward3a_P_hs(2100,4.3)
# Expecting:
#     60.78123340
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2616, in iapws.iapws97._Backward3a_P_hs
# Failed example:
#     _Backward3a_P_hs(2100,4.3)
# Expected:
#     60.78123340
# Got:
#     60.78123340465693
# Trying:
#     _Backward3a_T_Ph(20,1700)
# Expecting:
#     629.3083892
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2228, in iapws.iapws97._Backward3a_T_Ph
# Failed example:
#     _Backward3a_T_Ph(20,1700)
# Expected:
#     629.3083892
# Got:
#     629.308389159384
# Trying:
#     _Backward3a_T_Ph(100,2100)
# Expecting:
#     733.6163014
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2230, in iapws.iapws97._Backward3a_T_Ph
# Failed example:
#     _Backward3a_T_Ph(100,2100)
# Expected:
#     733.6163014
# Got:
#     733.6163014455943
# Trying:
#     _Backward3a_T_Ps(20,3.8)
# Expecting:
#     628.2959869
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2483, in iapws.iapws97._Backward3a_T_Ps
# Failed example:
#     _Backward3a_T_Ps(20,3.8)
# Expected:
#     628.2959869
# Got:
#     628.2959868694708
# Trying:
#     _Backward3a_T_Ps(100,4)
# Expecting:
#     705.6880237
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2485, in iapws.iapws97._Backward3a_T_Ps
# Failed example:
#     _Backward3a_T_Ps(100,4)
# Expected:
#     705.6880237
# Got:
#     705.6880236584724
# Trying:
#     _Backward3a_v_Ph(20,1700)
# Expecting:
#     0.001749903962
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2101, in iapws.iapws97._Backward3a_v_Ph
# Failed example:
#     _Backward3a_v_Ph(20,1700)
# Expected:
#     0.001749903962
# Got:
#     0.0017499039619738841
# Trying:
#     _Backward3a_v_Ph(100,2100)
# Expecting:
#     0.001676229776
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2103, in iapws.iapws97._Backward3a_v_Ph
# Failed example:
#     _Backward3a_v_Ph(100,2100)
# Expected:
#     0.001676229776
# Got:
#     0.0016762297761671319
# Trying:
#     _Backward3a_v_Ps(20,3.8)
# Expecting:
#     0.001733791463
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2357, in iapws.iapws97._Backward3a_v_Ps
# Failed example:
#     _Backward3a_v_Ps(20,3.8)
# Expected:
#     0.001733791463
# Got:
#     0.00173379146342528
# Trying:
#     _Backward3a_v_Ps(100,4)
# Expecting:
#     0.001555893131
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2359, in iapws.iapws97._Backward3a_v_Ps
# Failed example:
#     _Backward3a_v_Ps(100,4)
# Expected:
#     0.001555893131
# Got:
#     0.0015558931306057942
# Trying:
#     _Backward3b_P_hs(2400,4.7)
# Expecting:
#     63.63924887
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2668, in iapws.iapws97._Backward3b_P_hs
# Failed example:
#     _Backward3b_P_hs(2400,4.7)
# Expected:
#     63.63924887
# Got:
#     63.6392488735417
# Trying:
#     _Backward3b_P_hs(2600,5.1)
# Expecting:
#     34.34999263
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2670, in iapws.iapws97._Backward3b_P_hs
# Failed example:
#     _Backward3b_P_hs(2600,5.1)
# Expected:
#     34.34999263
# Got:
#     34.34999262770051
# Trying:
#     _Backward3b_P_hs(2700,5.0)
# Expecting:
#     88.39043281
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2672, in iapws.iapws97._Backward3b_P_hs
# Failed example:
#     _Backward3b_P_hs(2700,5.0)
# Expected:
#     88.39043281
# Got:
#     88.39043280879775
# Trying:
#     _Backward3b_T_Ph(20,2500)
# Expecting:
#     641.8418053
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2281, in iapws.iapws97._Backward3b_T_Ph
# Failed example:
#     _Backward3b_T_Ph(20,2500)
# Expected:
#     641.8418053
# Got:
#     641.8418053232451
# Trying:
#     _Backward3b_T_Ph(100,2700)
# Expecting:
#     842.0460876
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2283, in iapws.iapws97._Backward3b_T_Ph
# Failed example:
#     _Backward3b_T_Ph(100,2700)
# Expected:
#     842.0460876
# Got:
#     842.046087633262
# Trying:
#     _Backward3b_T_Ps(20,5)
# Expecting:
#     640.1176443
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2536, in iapws.iapws97._Backward3b_T_Ps
# Failed example:
#     _Backward3b_T_Ps(20,5)
# Expected:
#     640.1176443
# Got:
#     640.1176443357846
# Trying:
#     _Backward3b_T_Ps(100,5)
# Expecting:
#     847.4332825
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2538, in iapws.iapws97._Backward3b_T_Ps
# Failed example:
#     _Backward3b_T_Ps(100,5)
# Expected:
#     847.4332825
# Got:
#     847.4332824654258
# Trying:
#     _Backward3b_v_Ph(20,2500)
# Expecting:
#     0.006670547043
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2154, in iapws.iapws97._Backward3b_v_Ph
# Failed example:
#     _Backward3b_v_Ph(20,2500)
# Expected:
#     0.006670547043
# Got:
#     0.006670547042520642
# Trying:
#     _Backward3b_v_Ph(100,2700)
# Expecting:
#     0.002404234998
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2156, in iapws.iapws97._Backward3b_v_Ph
# Failed example:
#     _Backward3b_v_Ph(100,2700)
# Expected:
#     0.002404234998
# Got:
#     0.002404234997848506
# Trying:
#     _Backward3b_v_Ps(20,5)
# Expecting:
#     0.006262101987
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2409, in iapws.iapws97._Backward3b_v_Ps
# Failed example:
#     _Backward3b_v_Ps(20,5)
# Expected:
#     0.006262101987
# Got:
#     0.006262101986717017
# Trying:
#     _Backward3b_v_Ps(100,5)
# Expecting:
#     0.002449610757
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2411, in iapws.iapws97._Backward3b_v_Ps
# Failed example:
#     _Backward3b_v_Ps(100,5)
# Expected:
#     0.002449610757
# Got:
#     0.002449610756892614
# Trying:
#     _Backward3x_v_PT(630,50,"a")
# Expecting:
#     0.001470853100
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2974, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(630,50,"a")
# Expected:
#     0.001470853100
# Got:
#     0.001470853100110911
# Trying:
#     _Backward3x_v_PT(670,80,"a")
# Expecting:
#     0.001503831359
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2976, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(670,80,"a")
# Expected:
#     0.001503831359
# Got:
#     0.0015038313585404727
# Trying:
#     _Backward3x_v_PT(710,50,"b")
# Expecting:
#     0.002204728587
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2978, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(710,50,"b")
# Expected:
#     0.002204728587
# Got:
#     0.0022047285870574838
# Trying:
#     _Backward3x_v_PT(750,80,"b")
# Expecting:
#     0.001973692940
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2980, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(750,80,"b")
# Expected:
#     0.001973692940
# Got:
#     0.0019736929401211155
# Trying:
#     _Backward3x_v_PT(630,20,"c")
# Expecting:
#     0.001761696406
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2982, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(630,20,"c")
# Expected:
#     0.001761696406
# Got:
#     0.0017616964055295276
# Trying:
#     _Backward3x_v_PT(650,30,"c")
# Expecting:
#     0.001819560617
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2984, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(650,30,"c")
# Expected:
#     0.001819560617
# Got:
#     0.0018195606165288332
# Trying:
#     _Backward3x_v_PT(656,26,"d")
# Expecting:
#     0.002245587720
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2986, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(656,26,"d")
# Expected:
#     0.002245587720
# Got:
#     0.002245587720029806
# Trying:
#     _Backward3x_v_PT(670,30,"d")
# Expecting:
#     0.002506897702
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2988, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(670,30,"d")
# Expected:
#     0.002506897702
# Got:
#     0.002506897701629579
# Trying:
#     _Backward3x_v_PT(661,26,"e")
# Expecting:
#     0.002970225962
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2990, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(661,26,"e")
# Expected:
#     0.002970225962
# Got:
#     0.0029702259620031472
# Trying:
#     _Backward3x_v_PT(675,30,"e")
# Expecting:
#     0.003004627086
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2992, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(675,30,"e")
# Expected:
#     0.003004627086
# Got:
#     0.0030046270863580073
# Trying:
#     _Backward3x_v_PT(671,26,"f")
# Expecting:
#     0.005019029401
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2994, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(671,26,"f")
# Expected:
#     0.005019029401
# Got:
#     0.00501902940104471
# Trying:
#     _Backward3x_v_PT(690,30,"f")
# Expecting:
#     0.004656470142
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2996, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(690,30,"f")
# Expected:
#     0.004656470142
# Got:
#     0.004656470141685632
# Trying:
#     _Backward3x_v_PT(649,23.6,"g")
# Expecting:
#     0.002163198378
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2998, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649,23.6,"g")
# Expected:
#     0.002163198378
# Got:
#     0.0021631983783137196
# Trying:
#     _Backward3x_v_PT(650,24,"g")
# Expecting:
#     0.002166044161
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3000, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(650,24,"g")
# Expected:
#     0.002166044161
# Got:
#     0.0021660441609564836
# Trying:
#     _Backward3x_v_PT(652,23.6,"h")
# Expecting:
#     0.002651081407
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3002, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(652,23.6,"h")
# Expected:
#     0.002651081407
# Got:
#     0.0026510814065738545
# Trying:
#     _Backward3x_v_PT(654,24,"h")
# Expecting:
#     0.002967802335
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3004, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(654,24,"h")
# Expected:
#     0.002967802335
# Got:
#     0.0029678023349397832
# Trying:
#     _Backward3x_v_PT(653,23.6,"i")
# Expecting:
#     0.003273916816
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3006, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(653,23.6,"i")
# Expected:
#     0.003273916816
# Got:
#     0.00327391681593586
# Trying:
#     _Backward3x_v_PT(655,24,"i")
# Expecting:
#     0.003550329864
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3008, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(655,24,"i")
# Expected:
#     0.003550329864
# Got:
#     0.0035503298636594856
# Trying:
#     _Backward3x_v_PT(655,23.5,"j")
# Expecting:
#     0.004545001142
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3010, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(655,23.5,"j")
# Expected:
#     0.004545001142
# Got:
#     0.004545001141649382
# Trying:
#     _Backward3x_v_PT(660,24,"j")
# Expecting:
#     0.005100267704
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3012, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(660,24,"j")
# Expected:
#     0.005100267704
# Got:
#     0.005100267703573203
# Trying:
#     _Backward3x_v_PT(660,23,"k")
# Expecting:
#     0.006109525997
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3014, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(660,23,"k")
# Expected:
#     0.006109525997
# Got:
#     0.006109525996886692
# Trying:
#     _Backward3x_v_PT(670,24,"k")
# Expecting:
#     0.006427325645
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3016, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(670,24,"k")
# Expected:
#     0.006427325645
# Got:
#     0.0064273256447015745
# Trying:
#     _Backward3x_v_PT(646,22.6,"l")
# Expecting:
#     0.002117860851
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3018, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(646,22.6,"l")
# Expected:
#     0.002117860851
# Got:
#     0.0021178608506781027
# Trying:
#     _Backward3x_v_PT(646,23,"l")
# Expecting:
#     0.002062374674
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3020, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(646,23,"l")
# Expected:
#     0.002062374674
# Got:
#     0.002062374674146725
# Trying:
#     _Backward3x_v_PT(648.6,22.6,"m")
# Expecting:
#     0.002533063780
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3022, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(648.6,22.6,"m")
# Expected:
#     0.002533063780
# Got:
#     0.0025330637804214795
# Trying:
#     _Backward3x_v_PT(649.3,22.8,"m")
# Expecting:
#     0.002572971781
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3024, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649.3,22.8,"m")
# Expected:
#     0.002572971781
# Got:
#     0.0025729717809150334
# Trying:
#     _Backward3x_v_PT(649,22.6,"n")
# Expecting:
#     0.002923432711
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3026, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649,22.6,"n")
# Expected:
#     0.002923432711
# Got:
#     0.002923432710998241
# Trying:
#     _Backward3x_v_PT(649.7,22.8,"n")
# Expecting:
#     0.002913311494
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3028, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649.7,22.8,"n")
# Expected:
#     0.002913311494
# Got:
#     0.0029133114940412745
# Trying:
#     _Backward3x_v_PT(649.1,22.6,"o")
# Expecting:
#     0.003131208996
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3030, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649.1,22.6,"o")
# Expected:
#     0.003131208996
# Got:
#     0.003131208996006504
# Trying:
#     _Backward3x_v_PT(649.9,22.8,"o")
# Expecting:
#     0.003221160278
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3032, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649.9,22.8,"o")
# Expected:
#     0.003221160278
# Got:
#     0.0032211602779362867
# Trying:
#     _Backward3x_v_PT(649.4,22.6,"p")
# Expecting:
#     0.003715596186
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3034, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649.4,22.6,"p")
# Expected:
#     0.003715596186
# Got:
#     0.0037155961864872977
# Trying:
#     _Backward3x_v_PT(650.2,22.8,"p")
# Expecting:
#     0.003664754790
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3036, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(650.2,22.8,"p")
# Expected:
#     0.003664754790
# Got:
#     0.0036647547896187177
# Trying:
#     _Backward3x_v_PT(640,21.1,"q")
# Expecting:
#     0.001970999272
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3038, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(640,21.1,"q")
# Expected:
#     0.001970999272
# Got:
#     0.001970999271891958
# Trying:
#     _Backward3x_v_PT(643,21.8,"q")
# Expecting:
#     0.002043919161
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3040, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(643,21.8,"q")
# Expected:
#     0.002043919161
# Got:
#     0.002043919160913866
# Trying:
#     _Backward3x_v_PT(644,21.1,"r")
# Expecting:
#     0.005251009921
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3042, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(644,21.1,"r")
# Expected:
#     0.005251009921
# Got:
#     0.00525100992110033
# Trying:
#     _Backward3x_v_PT(648,21.8,"r")
# Expecting:
#     0.005256844741
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3044, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(648,21.8,"r")
# Expected:
#     0.005256844741
# Got:
#     0.005256844740780116
# Trying:
#     _Backward3x_v_PT(635,19.1,"s")
# Expecting:
#     0.001932829079
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3046, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(635,19.1,"s")
# Expected:
#     0.001932829079
# Got:
#     0.0019328290790263667
# Trying:
#     _Backward3x_v_PT(638,20,"s")
# Expecting:
#     0.001985387227
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3048, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(638,20,"s")
# Expected:
#     0.001985387227
# Got:
#     0.0019853872274726695
# Trying:
#     _Backward3x_v_PT(626,17,"t")
# Expecting:
#     0.008483262001
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3050, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(626,17,"t")
# Expected:
#     0.008483262001
# Got:
#     0.008483262001139871
# Trying:
#     _Backward3x_v_PT(640,20,"t")
# Expecting:
#     0.006227528101
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3052, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(640,20,"t")
# Expected:
#     0.006227528101
# Got:
#     0.006227528101006945
# Trying:
#     _Backward3x_v_PT(644.6,21.5,"u")
# Expecting:
#     0.002268366647
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3054, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(644.6,21.5,"u")
# Expected:
#     0.002268366647
# Got:
#     0.002268366646629464
# Trying:
#     _Backward3x_v_PT(646.1,22,"u")
# Expecting:
#     0.002296350553
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3056, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(646.1,22,"u")
# Expected:
#     0.002296350553
# Got:
#     0.0022963505532551556
# Trying:
#     _Backward3x_v_PT(648.6,22.5,"v")
# Expecting:
#     0.002832373260
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3058, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(648.6,22.5,"v")
# Expected:
#     0.002832373260
# Got:
#     0.002832373260251989
# Trying:
#     _Backward3x_v_PT(647.9,22.3,"v")
# Expecting:
#     0.002811424405
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3060, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(647.9,22.3,"v")
# Expected:
#     0.002811424405
# Got:
#     0.002811424404556844
# Trying:
#     _Backward3x_v_PT(647.5,22.15,"w")
# Expecting:
#     0.003694032281
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3062, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(647.5,22.15,"w")
# Expected:
#     0.003694032281
# Got:
#     0.003694032280598689
# Trying:
#     _Backward3x_v_PT(648.1,22.3,"w")
# Expecting:
#     0.003622226305
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3064, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(648.1,22.3,"w")
# Expected:
#     0.003622226305
# Got:
#     0.003622226305398735
# Trying:
#     _Backward3x_v_PT(648,22.11,"x")
# Expecting:
#     0.004528072649
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3066, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(648,22.11,"x")
# Expected:
#     0.004528072649
# Got:
#     0.004528072648832488
# Trying:
#     _Backward3x_v_PT(649,22.3,"x")
# Expecting:
#     0.004556905799
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3068, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(649,22.3,"x")
# Expected:
#     0.004556905799
# Got:
#     0.004556905798877278
# Trying:
#     _Backward3x_v_PT(646.84,22,"y")
# Expecting:
#     0.002698354719
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3070, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(646.84,22,"y")
# Expected:
#     0.002698354719
# Got:
#     0.0026983547189247956
# Trying:
#     _Backward3x_v_PT(647.05,22.064,"y")
# Expecting:
#     0.002717655648
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3072, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(647.05,22.064,"y")
# Expected:
#     0.002717655648
# Got:
#     0.0027176556481596707
# Trying:
#     _Backward3x_v_PT(646.89,22,"z")
# Expecting:
#     0.003798732962
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3074, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(646.89,22,"z")
# Expected:
#     0.003798732962
# Got:
#     0.0037987329624589563
# Trying:
#     _Backward3x_v_PT(647.15,22.064,"z")
# Expecting:
#     0.003701940009
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3076, in iapws.iapws97._Backward3x_v_PT
# Failed example:
#     _Backward3x_v_PT(647.15,22.064,"z")
# Expected:
#     0.003701940009
# Got:
#     0.003701940009484689
# Trying:
#     _Backward4_T_hs(1800,5.3)
# Expecting:
#     346.8475498
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3630, in iapws.iapws97._Backward4_T_hs
# Failed example:
#     _Backward4_T_hs(1800,5.3)
# Expected:
#     346.8475498
# Got:
#     346.8475497914448
# Trying:
#     _Backward4_T_hs(2400,6.0)
# Expecting:
#     425.1373305
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3632, in iapws.iapws97._Backward4_T_hs
# Failed example:
#     _Backward4_T_hs(2400,6.0)
# Expected:
#     425.1373305
# Got:
#     425.13733054525534
# Trying:
#     _Backward4_T_hs(2500,5.5)
# Expecting:
#     522.5579013
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3634, in iapws.iapws97._Backward4_T_hs
# Failed example:
#     _Backward4_T_hs(2500,5.5)
# Expected:
#     522.5579013
# Got:
#     522.5579013425315
# Trying:
#     _P23_T(623.15)
# Expecting:
#     16.52916425
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 177, in iapws.iapws97._P23_T
# Failed example:
#     _P23_T(623.15)
# Expected:
#     16.52916425
# Got:
#     16.529164252621626
# Trying:
#     _PSat_T(500)
# Expecting:
#     2.63889776
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 302, in iapws.iapws97._PSat_T
# Failed example:
#     _PSat_T(500)
# Expected:
#     2.63889776
# Got:
#     2.638897756273222
# Trying:
#     _PSat_h(1700)
# Expecting:
#     17.24175718
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 392, in iapws.iapws97._PSat_h
# Failed example:
#     _PSat_h(1700)
# Expected:
#     17.24175718
# Got:
#     17.241757178592714
# Trying:
#     _PSat_h(2400)
# Expecting:
#     20.18090839
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 394, in iapws.iapws97._PSat_h
# Failed example:
#     _PSat_h(2400)
# Expected:
#     20.18090839
# Got:
#     20.180908386815318
# Trying:
#     _PSat_s(3.8)
# Expecting:
#     16.87755057
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 445, in iapws.iapws97._PSat_s
# Failed example:
#     _PSat_s(3.8)
# Expected:
#     16.87755057
# Got:
#     16.87755056971136
# Trying:
#     _PSat_s(5.2)
# Expecting:
#     16.68968482
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 447, in iapws.iapws97._PSat_s
# Failed example:
#     _PSat_s(5.2)
# Expected:
#     16.68968482
# Got:
#     16.68968481727376
# Trying:
#     _P_2bc(3516.004323)
# Expecting:
#     100.0
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1105, in iapws.iapws97._P_2bc
# Failed example:
#     _P_2bc(3516.004323)
# Expected:
#     100.0
# Got:
#     100.00000002184379
# Trying:
#     _Region1(300,3)["v"]
# Expecting:
#     0.00100215168
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 728, in iapws.iapws97._Region1
# Failed example:
#     _Region1(300,3)["v"]
# Expected:
#     0.00100215168
# Got:
#     0.0010021516796866943
# Trying:
#     _Region1(300,3)["h"]
# Expecting:
#     115.331273
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 730, in iapws.iapws97._Region1
# Failed example:
#     _Region1(300,3)["h"]
# Expected:
#     115.331273
# Got:
#     115.3312730214384
# Trying:
#     _Region1(300,3)["h"]-3000*_Region1(300,3)["v"]
# Expecting:
#     112.324818
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 732, in iapws.iapws97._Region1
# Failed example:
#     _Region1(300,3)["h"]-3000*_Region1(300,3)["v"]
# Expected:
#     112.324818
# Got:
#     112.32481798237832
# Trying:
#     _Region1(300,80)["s"]
# Expecting:
#     0.368563852
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 734, in iapws.iapws97._Region1
# Failed example:
#     _Region1(300,80)["s"]
# Expected:
#     0.368563852
# Got:
#     0.36856385239848066
# Trying:
#     _Region1(300,80)["cp"]
# Expecting:
#     4.01008987
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 736, in iapws.iapws97._Region1
# Failed example:
#     _Region1(300,80)["cp"]
# Expected:
#     4.01008987
# Got:
#     4.010089869646331
# Trying:
#     _Region1(300,80)["cv"]
# Expecting:
#     3.91736606
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 738, in iapws.iapws97._Region1
# Failed example:
#     _Region1(300,80)["cv"]
# Expected:
#     3.91736606
# Got:
#     3.9173660618448736
# Trying:
#     _Region1(500,3)["w"]
# Expecting:
#     1240.71337
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 740, in iapws.iapws97._Region1
# Failed example:
#     _Region1(500,3)["w"]
# Expected:
#     1240.71337
# Got:
#     1240.7133731017252
# Trying:
#     _Region1(500,3)["alfav"]
# Expecting:
#     0.00164118128
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 742, in iapws.iapws97._Region1
# Failed example:
#     _Region1(500,3)["alfav"]
# Expected:
#     0.00164118128
# Got:
#     0.0016411812807641884
# Trying:
#     _Region1(500,3)["kt"]
# Expecting:
#     0.00112892188
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 744, in iapws.iapws97._Region1
# Failed example:
#     _Region1(500,3)["kt"]
# Expected:
#     0.00112892188
# Got:
#     0.0011289218770058733
# Trying:
#     _Region2(700,30)["v"]
# Expecting:
#     0.00542946619
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 965, in iapws.iapws97._Region2
# Failed example:
#     _Region2(700,30)["v"]
# Expected:
#     0.00542946619
# Got:
#     0.005429466194617729
# Trying:
#     _Region2(700,30)["h"]
# Expecting:
#     2631.49474
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 967, in iapws.iapws97._Region2
# Failed example:
#     _Region2(700,30)["h"]
# Expected:
#     2631.49474
# Got:
#     2631.4947448448074
# Trying:
#     _Region2(700,30)["h"]-30000*_Region2(700,30)["v"]
# Expecting:
#     2468.61076
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 969, in iapws.iapws97._Region2
# Failed example:
#     _Region2(700,30)["h"]-30000*_Region2(700,30)["v"]
# Expected:
#     2468.61076
# Got:
#     2468.6107590062757
# Trying:
#     _Region2(700,0.0035)["s"]
# Expecting:
#     10.1749996
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 971, in iapws.iapws97._Region2
# Failed example:
#     _Region2(700,0.0035)["s"]
# Expected:
#     10.1749996
# Got:
#     10.174999578595989
# Trying:
#     _Region2(700,0.0035)["cp"]
# Expecting:
#     2.08141274
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 973, in iapws.iapws97._Region2
# Failed example:
#     _Region2(700,0.0035)["cp"]
# Expected:
#     2.08141274
# Got:
#     2.0814127437023693
# Trying:
#     _Region2(700,0.0035)["cv"]
# Expecting:
#     1.61978333
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 975, in iapws.iapws97._Region2
# Failed example:
#     _Region2(700,0.0035)["cv"]
# Expected:
#     1.61978333
# Got:
#     1.619783325600298
# Trying:
#     _Region2(300,0.0035)["w"]
# Expecting:
#     427.920172
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 977, in iapws.iapws97._Region2
# Failed example:
#     _Region2(300,0.0035)["w"]
# Expected:
#     427.920172
# Got:
#     427.92017226310486
# Trying:
#     _Region2(300,0.0035)["alfav"]
# Expecting:
#     0.00337578289
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 979, in iapws.iapws97._Region2
# Failed example:
#     _Region2(300,0.0035)["alfav"]
# Expected:
#     0.00337578289
# Got:
#     0.0033757828943612863
# Trying:
#     _Region2(300,0.0035)["kt"]
# Expecting:
#     286.239651
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 981, in iapws.iapws97._Region2
# Failed example:
#     _Region2(300,0.0035)["kt"]
# Expected:
#     286.239651
# Got:
#     286.2396513918864
# Trying:
#     _Region3(500,650)["P"]
# Expecting:
#     25.5837018
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1782, in iapws.iapws97._Region3
# Failed example:
#     _Region3(500,650)["P"]
# Expected:
#     25.5837018
# Got:
#     25.583701818521945
# Trying:
#     _Region3(500,650)["h"]
# Expecting:
#     1863.43019
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1784, in iapws.iapws97._Region3
# Failed example:
#     _Region3(500,650)["h"]
# Expected:
#     1863.43019
# Got:
#     1863.43018983342
# Trying:
#     p = _Region3(500, 650)
# Expecting nothing
# ok
# Trying:
#     p["h"]-p["P"]*1000*p["v"]
# Expecting:
#     1812.26279
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1787, in iapws.iapws97._Region3
# Failed example:
#     p["h"]-p["P"]*1000*p["v"]
# Expected:
#     1812.26279
# Got:
#     1812.262786196376
# Trying:
#     _Region3(200,650)["s"]
# Expecting:
#     4.85438792
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1789, in iapws.iapws97._Region3
# Failed example:
#     _Region3(200,650)["s"]
# Expected:
#     4.85438792
# Got:
#     4.85438791974196
# Trying:
#     _Region3(200,650)["cp"]
# Expecting:
#     44.6579342
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1791, in iapws.iapws97._Region3
# Failed example:
#     _Region3(200,650)["cp"]
# Expected:
#     44.6579342
# Got:
#     44.65793415558166
# Trying:
#     _Region3(200,650)["cv"]
# Expecting:
#     4.04118076
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1793, in iapws.iapws97._Region3
# Failed example:
#     _Region3(200,650)["cv"]
# Expected:
#     4.04118076
# Got:
#     4.041180759550149
# Trying:
#     _Region3(200,650)["w"]
# Expecting:
#     383.444594
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1795, in iapws.iapws97._Region3
# Failed example:
#     _Region3(200,650)["w"]
# Expected:
#     383.444594
# Got:
#     383.44459420462636
# Trying:
#     _Region3(500,750)["alfav"]
# Expecting:
#     0.00441515098
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1797, in iapws.iapws97._Region3
# Failed example:
#     _Region3(500,750)["alfav"]
# Expected:
#     0.00441515098
# Got:
#     0.00441515098423961
# Trying:
#     _Region3(500,750)["kt"]
# Expecting:
#     0.00806710817
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1799, in iapws.iapws97._Region3
# Failed example:
#     _Region3(500,750)["kt"]
# Expected:
#     0.00806710817
# Got:
#     0.008067108166593676
# Trying:
#     _Region5(1500,0.5)["v"]
# Expecting:
#     1.38455090
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3695, in iapws.iapws97._Region5
# Failed example:
#     _Region5(1500,0.5)["v"]
# Expected:
#     1.38455090
# Got:
#     1.38455089878153
# Trying:
#     _Region5(1500,0.5)["h"]
# Expecting:
#     5219.76855
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3697, in iapws.iapws97._Region5
# Failed example:
#     _Region5(1500,0.5)["h"]
# Expected:
#     5219.76855
# Got:
#     5219.768551208338
# Trying:
#     _Region5(1500,0.5)["h"]-500*_Region5(1500,0.5)["v"]
# Expecting:
#     4527.49310
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3699, in iapws.iapws97._Region5
# Failed example:
#     _Region5(1500,0.5)["h"]-500*_Region5(1500,0.5)["v"]
# Expected:
#     4527.49310
# Got:
#     4527.493101817573
# Trying:
#     _Region5(1500,30)["s"]
# Expecting:
#     7.72970133
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3701, in iapws.iapws97._Region5
# Failed example:
#     _Region5(1500,30)["s"]
# Expected:
#     7.72970133
# Got:
#     7.729701326182764
# Trying:
#     _Region5(1500,30)["cp"]
# Expecting:
#     2.72724317
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3703, in iapws.iapws97._Region5
# Failed example:
#     _Region5(1500,30)["cp"]
# Expected:
#     2.72724317
# Got:
#     2.7272431722705295
# Trying:
#     _Region5(1500,30)["cv"]
# Expecting:
#     2.19274829
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3705, in iapws.iapws97._Region5
# Failed example:
#     _Region5(1500,30)["cv"]
# Expected:
#     2.19274829
# Got:
#     2.1927482936648652
# Trying:
#     _Region5(2000,30)["w"]
# Expecting:
#     1067.36948
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3707, in iapws.iapws97._Region5
# Failed example:
#     _Region5(2000,30)["w"]
# Expected:
#     1067.36948
# Got:
#     1067.3694787774248
# Trying:
#     _Region5(2000,30)["alfav"]
# Expecting:
#     0.000508830641
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3709, in iapws.iapws97._Region5
# Failed example:
#     _Region5(2000,30)["alfav"]
# Expected:
#     0.000508830641
# Got:
#     0.0005088306412790769
# Trying:
#     _Region5(2000,30)["kt"]
# Expecting:
#     0.0329193892
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 3711, in iapws.iapws97._Region5
# Failed example:
#     _Region5(2000,30)["kt"]
# Expected:
#     0.0329193892
# Got:
#     0.03291938922687314
# Trying:
#     _TSat_P(10)
# Expecting:
#     584.149488
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 346, in iapws.iapws97._TSat_P
# Failed example:
#     _TSat_P(10)
# Expected:
#     584.149488
# Got:
#     584.1494879985282
# Trying:
#     _h13_s(3.7)
# Expecting:
#     1632.525047
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 134, in iapws.iapws97._h13_s
# Failed example:
#     _h13_s(3.7)
# Expected:
#     1632.525047
# Got:
#     1632.525047325917
# Trying:
#     _h13_s(3.5)
# Expecting:
#     1566.104611
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 136, in iapws.iapws97._h13_s
# Failed example:
#     _h13_s(3.5)
# Expected:
#     1566.104611
# Got:
#     1566.104610977904
# Trying:
#     _h1_s(1)
# Expecting:
#     308.5509647
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 498, in iapws.iapws97._h1_s
# Failed example:
#     _h1_s(1)
# Expected:
#     308.5509647
# Got:
#     308.5509647482112
# Trying:
#     _h1_s(3)
# Expecting:
#     1198.359754
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 500, in iapws.iapws97._h1_s
# Failed example:
#     _h1_s(3)
# Expected:
#     1198.359754
# Got:
#     1198.3597538336894
# Trying:
#     _h2ab_s(7)
# Expecting:
#     2723.729985
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 610, in iapws.iapws97._h2ab_s
# Failed example:
#     _h2ab_s(7)
# Expected:
#     2723.729985
# Got:
#     2723.729984893315
# Trying:
#     _h2ab_s(9)
# Expecting:
#     2511.861477
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 612, in iapws.iapws97._h2ab_s
# Failed example:
#     _h2ab_s(9)
# Expected:
#     2511.861477
# Got:
#     2511.8614770502454
# Trying:
#     _h2c3b_s(5.5)
# Expecting:
#     2687.693850
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 670, in iapws.iapws97._h2c3b_s
# Failed example:
#     _h2c3b_s(5.5)
# Expected:
#     2687.693850
# Got:
#     2687.69385039889
# Trying:
#     _h2c3b_s(4.5)
# Expecting:
#     2144.360448
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 672, in iapws.iapws97._h2c3b_s
# Failed example:
#     _h2c3b_s(4.5)
# Expected:
#     2144.360448
# Got:
#     2144.360447929779
# Trying:
#     _h3a_s(3.8)
# Expecting:
#     1685.025565
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 556, in iapws.iapws97._h3a_s
# Failed example:
#     _h3a_s(3.8)
# Expected:
#     1685.025565
# Got:
#     1685.0255654229406
# Trying:
#     _h3a_s(4.2)
# Expecting:
#     1949.352563
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 558, in iapws.iapws97._h3a_s
# Failed example:
#     _h3a_s(4.2)
# Expected:
#     1949.352563
# Got:
#     1949.3525631744783
# Trying:
#     _h_3ab(25)
# Expecting:
#     2095.936454
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1867, in iapws.iapws97._h_3ab
# Failed example:
#     _h_3ab(25)
# Expected:
#     2095.936454
# Got:
#     2095.9364540465
# Trying:
#     _hab_s(7)
# Expecting:
#     3376.437884
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1160, in iapws.iapws97._hab_s
# Failed example:
#     _hab_s(7)
# Expected:
#     3376.437884
# Got:
#     3376.4378842575297
# Trying:
#     _hbc_P(100)
# Expecting:
#     3516.004323
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1132, in iapws.iapws97._hbc_P
# Failed example:
#     _hbc_P(100)
# Expected:
#     3516.004323
# Got:
#     3516.004322901269
# Trying:
#     _t_P(16.52916425)
# Expecting:
#     623.15
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 205, in iapws.iapws97._t_P
# Failed example:
#     _t_P(16.52916425)
# Expected:
#     623.15
# Got:
#     623.1499999763986
# Trying:
#     _t_hs(2600, 5.1)
# Expecting:
#     713.5259364
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 243, in iapws.iapws97._t_hs
# Failed example:
#     _t_hs(2600, 5.1)
# Expected:
#     713.5259364
# Got:
#     713.5259363904505
# Trying:
#     _t_hs(2800, 5.2)
# Expecting:
#     817.6202120
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 245, in iapws.iapws97._t_hs
# Failed example:
#     _t_hs(2800, 5.2)
# Expected:
#     817.6202120
# Got:
#     817.620212006425
# Trying:
#     _tab_P(40)
# Expecting:
#     693.0341408
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1896, in iapws.iapws97._tab_P
# Failed example:
#     _tab_P(40)
# Expected:
#     693.0341408
# Got:
#     693.0341408296053
# Trying:
#     _tef_P(40)
# Expecting:
#     713.9593992
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2004, in iapws.iapws97._tef_P
# Failed example:
#     _tef_P(40)
# Expected:
#     713.9593992
# Got:
#     713.959399239744
# Trying:
#     _top_P(22.8)
# Expecting:
#     650.0106943
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1932, in iapws.iapws97._top_P
# Failed example:
#     _top_P(22.8)
# Expected:
#     650.0106943
# Got:
#     650.010694314133
# Trying:
#     _twx_P(22.3)
# Expecting:
#     648.2049480
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 1968, in iapws.iapws97._twx_P
# Failed example:
#     _twx_P(22.3)
# Expected:
#     648.2049480
# Got:
#     648.204947950734
# Trying:
#     _txx_P(25,"cd")
# Expecting:
#     649.3659208
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2034, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(25,"cd")
# Expected:
#     649.3659208
# Got:
#     649.3659208321279
# Trying:
#     _txx_P(23,"gh")
# Expecting:
#     649.8873759
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2036, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(23,"gh")
# Expected:
#     649.8873759
# Got:
#     649.8873759273156
# Trying:
#     _txx_P(23,"ij")
# Expecting:
#     651.5778091
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2038, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(23,"ij")
# Expected:
#     651.5778091
# Got:
#     651.5778090636443
# Trying:
#     _txx_P(23,"jk")
# Expecting:
#     655.8338344
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2040, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(23,"jk")
# Expected:
#     655.8338344
# Got:
#     655.8338343776644
# Trying:
#     _txx_P(22.8,"mn")
# Expecting:
#     649.6054133
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2042, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(22.8,"mn")
# Expected:
#     649.6054133
# Got:
#     649.6054132953997
# Trying:
#     _txx_P(22,"qu")
# Expecting:
#     645.6355027
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2044, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(22,"qu")
# Expected:
#     645.6355027
# Got:
#     645.6355027340121
# Trying:
#     _txx_P(22,"rx")
# Expecting:
#     648.2622754
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2046, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(22,"rx")
# Expected:
#     648.2622754
# Got:
#     648.2622753670172
# Trying:
#     _txx_P(22.3,"uv")
# Expecting:
#     647.7996121
# **********************************************************************
# File "C:\Python35\lib\site-packages\iapws\iapws97.py", line 2048, in iapws.iapws97._txx_P
# Failed example:
#     _txx_P(22.3,"uv")
# Expected:
#     647.7996121
# Got:
#     647.7996121480069
# 35 items had no tests:
#     iapws.iapws97
#     iapws.iapws97.IAPWS97.__call__
#     iapws.iapws97.IAPWS97.__init__
#     iapws.iapws97.IAPWS97.calculable
#     iapws.iapws97.IAPWS97.calculo
#     iapws.iapws97.IAPWS97.derivative
#     iapws.iapws97.IAPWS97.fill
#     iapws.iapws97.IAPWS97_PT
#     iapws.iapws97.IAPWS97_PT.__init__
#     iapws.iapws97.IAPWS97_Ph
#     iapws.iapws97.IAPWS97_Ph.__init__
#     iapws.iapws97.IAPWS97_Ps
#     iapws.iapws97.IAPWS97_Ps.__init__
#     iapws.iapws97.IAPWS97_Px
#     iapws.iapws97.IAPWS97_Px.__init__
#     iapws.iapws97.IAPWS97_Tx
#     iapws.iapws97.IAPWS97_Tx.__init__
#     iapws.iapws97.Region2_cp0
#     iapws.iapws97.Region5_cp0
#     iapws.iapws97._Backward2_P_hs
#     iapws.iapws97._Backward2_T_Ph
#     iapws.iapws97._Backward2_T_Ps
#     iapws.iapws97._Backward3_P_hs
#     iapws.iapws97._Backward3_T_Ph
#     iapws.iapws97._Backward3_T_Ps
#     iapws.iapws97._Backward3_sat_v_P
#     iapws.iapws97._Backward3_v_PT
#     iapws.iapws97._Backward3_v_Ph
#     iapws.iapws97._Backward3_v_Ps
#     iapws.iapws97._Bound_Ph
#     iapws.iapws97._Bound_Ps
#     iapws.iapws97._Bound_TP
#     iapws.iapws97._Bound_hs
#     iapws.iapws97._Region4
#     iapws.iapws97.prop0
# **********************************************************************
# 50 items had failures:
#    3 of   6 in iapws.iapws97.IAPWS97
#    3 of   3 in iapws.iapws97._Backward1_P_hs
#    2 of   2 in iapws.iapws97._Backward1_T_Ph
#    2 of   2 in iapws.iapws97._Backward1_T_Ps
#    3 of   3 in iapws.iapws97._Backward2a_P_hs
#    2 of   2 in iapws.iapws97._Backward2a_T_Ph
#    2 of   2 in iapws.iapws97._Backward2a_T_Ps
#    3 of   3 in iapws.iapws97._Backward2b_P_hs
#    2 of   2 in iapws.iapws97._Backward2b_T_Ph
#    2 of   2 in iapws.iapws97._Backward2b_T_Ps
#    3 of   3 in iapws.iapws97._Backward2c_P_hs
#    2 of   2 in iapws.iapws97._Backward2c_T_Ph
#    2 of   2 in iapws.iapws97._Backward2c_T_Ps
#    3 of   3 in iapws.iapws97._Backward3a_P_hs
#    2 of   2 in iapws.iapws97._Backward3a_T_Ph
#    2 of   2 in iapws.iapws97._Backward3a_T_Ps
#    2 of   2 in iapws.iapws97._Backward3a_v_Ph
#    2 of   2 in iapws.iapws97._Backward3a_v_Ps
#    3 of   3 in iapws.iapws97._Backward3b_P_hs
#    2 of   2 in iapws.iapws97._Backward3b_T_Ph
#    2 of   2 in iapws.iapws97._Backward3b_T_Ps
#    2 of   2 in iapws.iapws97._Backward3b_v_Ph
#    2 of   2 in iapws.iapws97._Backward3b_v_Ps
#   52 of  52 in iapws.iapws97._Backward3x_v_PT
#    3 of   3 in iapws.iapws97._Backward4_T_hs
#    1 of   1 in iapws.iapws97._P23_T
#    1 of   1 in iapws.iapws97._PSat_T
#    2 of   2 in iapws.iapws97._PSat_h
#    2 of   2 in iapws.iapws97._PSat_s
#    1 of   1 in iapws.iapws97._P_2bc
#    9 of   9 in iapws.iapws97._Region1
#    9 of   9 in iapws.iapws97._Region2
#    9 of  10 in iapws.iapws97._Region3
#    9 of   9 in iapws.iapws97._Region5
#    1 of   1 in iapws.iapws97._TSat_P
#    2 of   2 in iapws.iapws97._h13_s
#    2 of   2 in iapws.iapws97._h1_s
#    2 of   2 in iapws.iapws97._h2ab_s
#    2 of   2 in iapws.iapws97._h2c3b_s
#    2 of   2 in iapws.iapws97._h3a_s
#    1 of   1 in iapws.iapws97._h_3ab
#    1 of   1 in iapws.iapws97._hab_s
#    1 of   1 in iapws.iapws97._hbc_P
#    1 of   1 in iapws.iapws97._t_P
#    2 of   2 in iapws.iapws97._t_hs
#    1 of   1 in iapws.iapws97._tab_P
#    1 of   1 in iapws.iapws97._tef_P
#    1 of   1 in iapws.iapws97._top_P
#    1 of   1 in iapws.iapws97._twx_P
#    8 of   8 in iapws.iapws97._txx_P
# 184 tests in 85 items.
# 4 passed and 180 failed.
# ***Test Failed*** 180 failures.

# %% [markdown]
# ## Further Reading
#
# doctest – Testing through documentation
#
#    https://pymotw.com/2/doctest/index.html
